# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_excel("/Users/haraldaarskog/Desktop/OUS_data.xlsx",sheet="Ark1")
#df = pd.DataFrame(data,header=0)
print(df)
# Out:
#       kilde       lab modalitet_norako examdato_benyttet_dt  \
# 0       RAD  RAD-. TS               MR           2017-05-12
# 1       RAD  RAD-. TS               MR           2017-05-12
# 2       RAD  RAD-. TS               MR           2017-06-26
# 3       RAD  RAD-. TS               MR           2018-02-22
# 4       RAD  RAD-. TS               CT           2017-09-07
# ...     ...       ...              ...                  ...
# 32017   RAD  RAD-. TS               RG           2019-10-26
# 32018   RAD  RAD-. TS               MR           2019-10-26
# 32019   RAD  RAD-. TS               CT           2019-10-25
# 32020   RAD  RAD-. TS               CT           2019-10-25
# 32021   RAD  RAD-. TS               CT           2019-10-25
#
#                          EXAMTYPE  tilsendt_ts  \
# 0                        MR Caput          1.0
# 1                        MR Caput          1.0
# 2                        MR Caput          1.0
# 3                        MR Caput          1.0
# ...
